# %%
#PROJETO montar uma aplicação de 4 listas, duas devem ser geradas por entrada manual e as demais serão geradas por meios de funçãos diferentes # USUARIO NAO PODE INFORMAR O NUMERO DE ENTRADAS #
#entregas
# Fluxograma do projeto
# Texto descritivo do problema
# codigo python
#DEADLINE - SEXTA-FEIRA 31/05 (APRESENTAR RODANDO)#
#VALOR 03 PONTOS #

# %%
# matplotlib = saída.
# numpy = estrutura dimensional ex: 1D 2D, 3D,4D....
# scipy = calculo...limites variações todo calculo possivel.
# tres biblioteca principais do Python



import numpy as np
#abreviação de numpy sempre adicionar "as np"

import matplotlib.pyplot as plt
#abreviação de matplotlib.puplot sempre adicionar "as plt"

x = np.linspace (0 ,2 * np.pi, 20)
y = np.sin(x)

yp = None
xi = np.linspace (x[0], x[-1], 100)
yi = np.interp (xi , x, y, yp)

print (len(x))
print (x)

print (len(y))
print (y)

fig, ax = plt.subplots()

ax.plot(x,y, 'o', xi, yi, '. r')

plt.show()

print ('..end application')
# Out:
# 20
# [0.         0.33069396 0.66138793 0.99208189 1.32277585 1.65346982
#  1.98416378 2.31485774 2.64555171 2.97624567 3.30693964 3.6376336
#  3.96832756 4.29902153 4.62971549 4.96040945 5.29110342 5.62179738
#  5.95249134 6.28318531]
# 20
# [ 0.00000000e+00  3.24699469e-01  6.14212713e-01  8.37166478e-01
#   9.69400266e-01  9.96584493e-01  9.15773327e-01  7.35723911e-01
#   4.75947393e-01  1.64594590e-01 -1.64594590e-01 -4.75947393e-01
#  -7.35723911e-01 -9.15773327e-01 -9.96584493e-01 -9.69400266e-01
#  -8.37166478e-01 -6.14212713e-01 -3.24699469e-01 -2.44929360e-16]
# ..end application

# %%
#Listas
lst_1 = ['Calculo1', 'Log de prog', 'Inter cienc com' , 'Relaçoes etnicas']
lst_2 = [1,2,3,4,5,6]
lst_3 = ["a","b","c","d"]
lst_4 = ["jose", 34, 43.32,'s']
lst_t = [lst_1, lst_2, lst_3, lst_4]

print (lst_2)
lst_2[3] = "zz"
print (lst_2)
lst_2.append ("Jose Maria")
print(lst_2)
print(lst_2[0])
print(lst_2[len(lst_2)-1])
print(lst_2[-1])

x = np.linspace (0 ,2 * np.pi, 20)
print (type(x))

# %%
#lst_1, lst_2 = [1,2,3,4,5,6], ['a',11 'jose','livro',3.4]

#lst_1, lst_2 = [1,2,3,4,5,6], ['a',11 'jose','livro',3.4]

lst = [1,2,3,4,5,6]
print ('Valor maximo é :', max(lst)) # maior valor da lista
print ('Valor maximo é :', min(lst)) # menor valor da lista

# %%
nome = "Chistopher Cattani"
lst = list(nome)
#lst = list(nome.upper())

print (nome)
print (lst)
print ('Numero de Ocorrencia da letra é : ', lst.count('a'))
print ('Numero de Ocorrencia da letra é : ', lst.count('x'))

# %%
lst_nome = list("Chris")
lst_val = list(range(5))

print (lst_val)
print (lst_nome)

lst_val.extend(lst_nome)
print(lst_val)

#lst_val.remove('C') #remover algo da lista
#print(lst_val)

print(lst_val.index('C')) #identificar a posição da variavel na lista

# %%
lst = list ('Christopher Pedro Cattani')
print(lst)
print (lst.sort())
# Out:
# ['C', 'h', 'r', 'i', 's', 't', 'o', 'p', 'h', 'e', 'r', ' ', 'P', 'e', 'd', 'r', 'o', ' ', 'C', 'a', 't', 't', 'a', 'n', 'i']
# None

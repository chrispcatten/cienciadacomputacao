# %%
import numpy as np

lst = list (np.arange(0.0,100,0.001))
#print (len(lst))
#print (lst)
for i in lst : 
  print(i)

# %%
lst_b =['vodka','breja','tequila','bomberinho','farmacia']
lst_b.append('conhaque')
print(lst_b)
del lst_b[3]
print (lst_b)

#atualizar uma posicao na lista
#lst_b [-1] = 'pinga'
#print(lst_b[-1])
#print (lst_b)


#
copo = lst_b[-1]
print (copo)
lst_b[-1] = 'pinga'
lst_b.append (copo)
print (lst_b)

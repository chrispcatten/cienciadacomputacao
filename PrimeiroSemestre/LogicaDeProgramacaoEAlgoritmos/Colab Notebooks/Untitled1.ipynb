# %%
nome    = []
veiculo = []
valor   = [] 
ipva1    = []
seguro1  = []

def printa_valor():
  for p, n in enumerate (nome):
    print ("{} - {} - {}".format(n, valor[p], ipva[p], seguro[p]))

  print('....')
  

   
while True:
  v_nome = input ('Informe o Nome .: ')
  if v_nome.upper() == "FIM":
    break
  v_veiculo = input ('Informe o Nome do veiculo .: ') 

  v_valor = float (input('Informe o Valor do Veículo .: '))
  def calcula ():
 
    ipva     = v_valor * 0.04
    seguro   = v_valor * 0.0235
  
  nome.append   (v_nome)
  veiculo.append(v_veiculo)
  valor.append  (v_valor)
  seguro1.append((calcula(seguro))
  ipva1.append   ((calcula(ipva))
  
print (nome)
print (veiculo)
print (valor)
print (ipva1)
print (seguro1)

print ('|..End Application')
# Out:
#   File "<ipython-input-36-9867e1b2b6ca>", line 31
#     ipva1.append   ((calcula(ipva))
#         ^
# SyntaxError: invalid syntax

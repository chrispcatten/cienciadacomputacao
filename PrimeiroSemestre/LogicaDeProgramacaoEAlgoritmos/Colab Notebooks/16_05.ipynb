# %%
#Gráfico 01

import numpy as np                # gerador de dados
import matplotlib.pyplot as plt   # plotagem de gráfico

x = np.arange (-10.0 , 10.0, 0.001) #Geração dos dados (vetor)
y = x**2                            # implementar a função


# Plotagem do grafico
papel, caneta = plt.subplots() # Criando osobjetos para plotagem
caneta.plot(x,y) # plotando o grafico

plt.show()   # apresentar o grafico

print(len(x))
print ('By Christopher')
# Out:
# 20000
# By Christopher

# %%
# Gráfico 02

import numpy as np                # gerador de dados
import matplotlib.pyplot as plt   # plotagem de gráfico

x = np.arange (-10.0 , 10.0, 0.001) #Geração dos dados (vetor)
y = np.sin(x + (2 *np.pi* x))                            # implementar a função


# Plotagem do grafico
papel, caneta = plt.subplots() # Criando osobjetos para plotagem
caneta.plot(x,y, 'r') # plotando o grafico

plt.show()   # apresentar o grafico

print(len(x))
print ('By Christopher')
# Out:
# 20000
# By Christopher

# %%
# Gráfico 03

import numpy as np                # gerador de dados
import matplotlib.pyplot as plt   # plotagem de gráfico

x = np.arange (-10.0 , 10.0, 0.001) # Geração dos dados (vetor)
y = np.cos((np.pi/6)+(4*np.pi*x))   # implementar a função


# Plotagem do grafico
papel, caneta = plt.subplots() # Criando osobjetos para plotagem
caneta.plot(x,y, 'g') # plotando o grafico

plt.show()   # apresentar o grafico

print(len(x))
print ('By Christopher')
# Out:
# 20000
# By Christopher

# %%
# Gráfico 04

import numpy as np                # gerador de dados
import matplotlib.pyplot as plt   # plotagem de gráfico

x = np.arange (-10.0 , 10.0, 0.001) #Geração dos dados (vetor)
y = []                              # implementar a função
for v in x:
  if v <= 1:
    y.append(1-v)
  if v> 1:
    y.append(v**2)

# Plotagem do grafico
papel, caneta = plt.subplots() # Criando osobjetos para plotagem
caneta.plot(x,y, 'm') # plotando o grafico

plt.show()   # apresentar o grafico

print(len(x))
print ('By Christopher')
# Out:
# 20000

# %%
# Gráfico 05

import numpy as np                # gerador de dados
import matplotlib.pyplot as plt   # plotagem de gráfico

x = np.arange (-10.0 , 10.0, 0.001) #Geração dos dados (vetor)
y = -(x-1) - (x+2)

# Plotagem do grafico
papel, caneta = plt.subplots() # Criando osobjetos para plotagem
caneta.plot(x,y, 'y') # plotando o grafico

plt.show()   # apresentar o grafico

print(len(x))
print ('By Christopher')
# Out:
# 20000

# %%
# Gráfico 05

import numpy as np                # gerador de dados
import matplotlib.pyplot as plt   # plotagem de gráfico

x = np.arange (-10.0 , 10.0, 0.001) #Geração dos dados (vetor)
y = -(x**3 - (2.5*x))

# Plotagem do grafico
papel, caneta = plt.subplots() # Criando osobjetos para plotagem
caneta.plot(x,y, 'r') # plotando o grafico

plt.show()   # apresentar o grafico

print(len(x))
print ('By Christopher')
# Out:
# 20000
# By Christopher

# %%
# Gráfico 06

import numpy as np                # gerador de dados
import matplotlib.pyplot as plt   # plotagem de gráfico

x = np.arange (-10.0 , 10.0, 0.001) #Geração dos dados (vetor)
y = 

# Plotagem do grafico
papel, caneta = plt.subplots() # Criando osobjetos para plotagem
caneta.plot(x,y, 'r') # plotando o grafico

plt.show()   # apresentar o grafico

print(len(x))
